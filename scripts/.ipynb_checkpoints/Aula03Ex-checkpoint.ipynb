# %% [markdown]
# ## Atividade 01
# exemplo de uso das funcoes da aula 03 com amostra de dados

# %%
# import needed libraries
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# get path to folder with files
path='D:/ENS410064/Dados/DataENS/ObsFlow_SWAT/diario19902012/'

# list and print files on dir
files = os.listdir(path)
print('estas sao as estacoes salvas na pasta:',files)
# Out:
# estas sao as estacoes salvas na pasta: ['65028000.txt', '65035000.txt', '65060000.txt', '65100000.txt', '65135000.txt', '65136550.txt', '65155000.txt', '65175000.txt', '65310000.txt', '65365800.txt', '65370000.txt', '65383500.txt', '65764000.txt', '65775900.txt', '65825000.txt', '65855000.txt', '65925000.txt', '65927000.txt', '65945000.txt', '65955000.txt', '65960000.txt', '65962000.txt', '65970000.txt', '65975000.txt', '65979000.txt', '65987000.txt', '65990550.txt', '65993000.txt']

# %%
del(allData,all,allD,dtime,dt) #deletar variavel, caso haja
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 del(allData,all,allD,dtime,dt) #deletar variavel, caso haja
#
# NameError: name 'allData' is not defined

# %%
allData = [pd.read_csv(path+file) for file in files] # ler txts e colocar na lista
type(allData)
# Out:
# list

# %%
all = pd.concat(allData, axis=1) # concatenar em um df?

all.columns = [file[0:8] for file in files] # nomes das colunas conforme arquivos
type(all)
# Out:
# pandas.core.frame.DataFrame

# %%
#del(dtime)
dtime = pd.date_range(start='1990-01-01 00:00:00', end='2012-12-31 00:00:00', freq='D')
dtime
type(dtime)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
dtime['Year']=dtime.Year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 dtime['Year']=dtime.Year
#
# AttributeError: 'DatetimeIndex' object has no attribute 'Year'

# %%
all['datetime'] = dtime
all
# Out:
#       65028000  65035000  65060000  65100000  65135000  65136550  65155000  \
# 0          NaN     94.94     73.00     61.16     24.48     36.14     31.20
# 1          NaN    140.75     84.35    127.85     29.32     48.24     41.30
# 2          NaN    159.50    115.00    165.00     30.00     51.18     46.24
# 3          NaN    163.30    134.00    151.00     28.12     51.42     47.52
# 4          NaN    166.35    143.60    123.25     27.75     49.68     49.12
# ...        ...       ...       ...       ...       ...       ...       ...
# 8396     39.08     42.83     79.03     39.05      5.76       NaN     12.34
# 8397     45.92     49.02     73.83     54.62      6.89       NaN     12.06
# 8398     62.59     61.90     67.33     85.36     10.23       NaN     11.78
# 8399     71.24     83.95     83.37    183.00     38.00       NaN     11.40
# 8400     88.26     91.50     99.60    201.80     46.16       NaN     10.92
#
# ...

# %%
# transforma em datetime
all['datetime'] = pd.to_datetime(all['datetime'])
all
# Out:
#       65028000  65035000  65060000  65100000  65135000  65136550  65155000  \
# 0          NaN     94.94     73.00     61.16     24.48     36.14     31.20
# 1          NaN    140.75     84.35    127.85     29.32     48.24     41.30
# 2          NaN    159.50    115.00    165.00     30.00     51.18     46.24
# 3          NaN    163.30    134.00    151.00     28.12     51.42     47.52
# 4          NaN    166.35    143.60    123.25     27.75     49.68     49.12
# ...        ...       ...       ...       ...       ...       ...       ...
# 8396     39.08     42.83     79.03     39.05      5.76       NaN     12.34
# 8397     45.92     49.02     73.83     54.62      6.89       NaN     12.06
# 8398     62.59     61.90     67.33     85.36     10.23       NaN     11.78
# 8399     71.24     83.95     83.37    183.00     38.00       NaN     11.40
# 8400     88.26     91.50     99.60    201.80     46.16       NaN     10.92
#
# ...

# %%
# transforma datetime em index
all.set_index('datetime', inplace=True)

# %%
print(all.index) #confere
# Out:
# DatetimeIndex(['1990-01-01', '1990-01-02', '1990-01-03', '1990-01-04',
#                '1990-01-05', '1990-01-06', '1990-01-07', '1990-01-08',
#                '1990-01-09', '1990-01-10',
#                ...
#                '2012-12-22', '2012-12-23', '2012-12-24', '2012-12-25',
#                '2012-12-26', '2012-12-27', '2012-12-28', '2012-12-29',
#                '2012-12-30', '2012-12-31'],
#               dtype='datetime64[ns]', name='datetime', length=8401, freq=None)

# %%
# cria colunas mes ano dia
all.index.year
all['year'] = all.index.year
all['month'] = all.index.month
all['day'] = all.index.day
all
# Out:
#             65028000  65035000  65060000  65100000  65135000  65136550  \
# datetime
# 1990-01-01       NaN     94.94     73.00     61.16     24.48     36.14
# 1990-01-02       NaN    140.75     84.35    127.85     29.32     48.24
# 1990-01-03       NaN    159.50    115.00    165.00     30.00     51.18
# 1990-01-04       NaN    163.30    134.00    151.00     28.12     51.42
# 1990-01-05       NaN    166.35    143.60    123.25     27.75     49.68
# ...              ...       ...       ...       ...       ...       ...
# 2012-12-27     39.08     42.83     79.03     39.05      5.76       NaN
# 2012-12-28     45.92     49.02     73.83     54.62      6.89       NaN
# 2012-12-29     62.59     61.90     67.33     85.36     10.23       NaN
# 2012-12-30     71.24     83.95     83.37    183.00     38.00       NaN
# 2012-12-31     88.26     91.50     99.60    201.80     46.16       NaN
#
#             65155000  65175000  65310000  65365800  ...  65962000  65970000  \
# ...

# %%
# salvar dataframe
all.to_csv('D:/ENS410064/Dados/ExAulas/'+'dfaula.csv')

# %%
# abrir dataframe
# Sort the DataFrame by the index
#df.sort_index(inplace=True)

# %%
all.iloc[0:10,27:31]
# Out:
#             65993000  year  month  day
# datetime
# 1990-01-01     664.4  1990      1    1
# 1990-01-02     608.6  1990      1    2
# 1990-01-03     627.2  1990      1    3
# 1990-01-04     683.0  1990      1    4
# 1990-01-05     720.2  1990      1    5
# 1990-01-06    1108.5  1990      1    6
# 1990-01-07     720.2  1990      1    7
# 1990-01-08     655.1  1990      1    8
# 1990-01-09     599.3  1990      1    9
# 1990-01-10     551.0  1990      1   10

# %%
#fazer medias
all_month = all.resample('M').mean() # serie de vazoes medias mensais
all_month
# Out:
#              65028000    65035000    65060000    65100000   65135000  \
# datetime
# 1990-01-31        NaN  232.710968  383.298387  225.648710  33.198710
# 1990-02-28        NaN  103.579286  196.966071   88.466786  15.009286
# 1990-03-31        NaN   98.512258  122.885806   77.256774  11.691613
# 1990-04-30        NaN   74.892667  128.093000   75.735000  12.144333
# 1990-05-31        NaN   72.320968  131.133548   78.168387  13.890000
# ...               ...         ...         ...         ...        ...
# 2012-08-31  34.692581   41.084194   89.968065   85.098387   9.083226
# 2012-09-30  28.753667   30.620333   47.135000   37.069667   6.014667
# 2012-10-31  39.602903   43.740000   62.440968   44.013548   7.214839
# 2012-11-30  40.980667   47.502333   91.425667   47.560667   7.586000
# 2012-12-31  54.972581   59.777742   74.981290   49.013548   9.088387
#
#              65136550    65155000    65175000     65310000     65365800  ...  \
# ...

# %%
# medias mensais
all_month.groupby(all_month.month).mean() # medias mensais
# Out:
#         65028000    65035000    65060000    65100000   65135000   65136550  \
# month
# 1.0    90.175726  110.412426  170.506718  101.386241  17.805105  28.150906
# 2.0    92.677320  109.428768  177.703495   93.856470  18.297103  28.968267
# 3.0    69.604808   86.381276  138.830281   74.219523  13.254853  22.087250
# 4.0    52.333270   62.881739  103.790971   63.940986  10.220522  17.519317
# 5.0    50.312442   61.037391  110.110575   65.390365   9.744446  17.089432
# 6.0    53.814413   67.077580  129.229913   77.258507  11.232754  17.876143
# 7.0    62.355545   80.981360  137.242314   89.654727  12.874250  22.627250
# 8.0    53.992780   70.745736  125.412146   78.155849  11.432160  17.815576
# 9.0    66.942413   85.187261  136.759275   88.540203  13.354058  21.966095
# 10.0   80.136144  103.685750  195.435316  112.591669  15.602917  25.683088
# 11.0   59.034524   73.115768  128.860319   77.927652  11.774478  19.688302
# ...

# %%
# plotar medias mensais

# %%
# plotar vazao diaria
import matplotlib.pyplot as plt
fig, ax = plt.subplots(3)
ax[0].plot(all)
ax[1].plot(all)

# %%
# calcular Q7,10

# %%
# fazer coluna com datenum para estatisticas
# criando vetor temporal de datas
dtime = np.arange(np.datetime64("1990-01-01 00:00:00"), np.datetime64("2013-01-01 00:00:00") , np.timedelta64 (1, "D"))
print(dtime.shape)
print(type(dtime))
print(dtime[0:10])
print(dtime[8390:8401])
dtime

# %%
# converte para df
dt = pd.DataFrame()
dt['datetime'] = dtime
print(dt)
type(dt)

# %%
 for file in files:
    if file.endswith('.txt'):
        # print(file)        
        dataF = pd.read_csv(path+file)
        allData.append(dataF)       # limpar variavel temporaria dataF ??
allD = pd.concat(allData, axis=1) # concatenar em um df?
allD.columns = [file[1:8] for file in files] # nomes das colunas conforme arquivos
