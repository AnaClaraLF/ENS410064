# %% [markdown]
# ## Aula 03 - python

# %% [markdown]
# Nesta aula veremos:
# 1. Numpy arrays e pandas Dataframes
# 2. Open and export files
# 3. Condition statements
# 4. Loops em pythin
# 5. Functions - def

# %% [markdown]
# 1.1 Numpy arrays

# %%
import numpy as np

#criando um vetor de dados aleatorio
data = np.random.rand(1000,2)
#verificando tamanho do vetor
print(data.shape)
print(np.size(data))
# print amostra de dados, primeiros dados
print(data[0:10])
print(data[0:10].shape)
# Out:
# (1000, 2)
# 2000
# [[0.00280437 0.6293511 ]
#  [0.09325328 0.24018662]
#  [0.89213683 0.48945191]
#  [0.8767391  0.32959925]
#  [0.28538564 0.98299388]
#  [0.57487498 0.22071989]
#  [0.0701022  0.99974464]
#  [0.22197354 0.3824103 ]
#  [0.28220469 0.64855413]
#  [0.98776116 0.7653861 ]]
# (10, 2)

# %%
# usando monte-carlo
dataMax = 1000
dataMin = 10
data = (dataMax - dataMin) * data + dataMin
print(data[0:10])
# Out:
# [[ 12.77632706 633.0575867 ]
#  [102.32074796 247.78475255]
#  [893.21546419 494.55739457]
#  [877.9717064  336.30325723]
#  [292.53178366 983.16394376]
#  [579.12622795 228.5126903 ]
#  [ 79.40117344 999.74718935]
#  [229.75380152 388.58619968]
#  [289.38264328 652.06859147]
#  [987.88354602 767.73223702]]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(3)
ax[0].plot(data)
ax[1].plot(data[:,1])
ax[2].plot(data[:,0])

# %%
# criando um dado 2D formato senoidal
data3d = np.sin(np.random.rand(1000,1000))
# plotando um dado 3D
fig2, ax2 = plt.subplots()
ax2.pcolor(data3d)

# %%
# criando vetor temporal de datas
dtime = np.arange(np.datetime64("2022-01-01"), np.datetime64("2023-01-01") , np.timedelta64 (1, "h"))
print(dtime[0:10])
print(dtime.shape)
print(type(dtime))
# Out:
# ['2022-01-01T00' '2022-01-01T01' '2022-01-01T02' '2022-01-01T03'
#  '2022-01-01T04' '2022-01-01T05' '2022-01-01T06' '2022-01-01T07'
#  '2022-01-01T08' '2022-01-01T09']
# (8760,)
# <class 'numpy.ndarray'>

# %% [markdown]
# ## PANDAS

# %%
import pandas as pd
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df['datetime'] = dtime
df
# Out:
#                 datetime
# 0    2022-01-01 00:00:00
# 1    2022-01-01 01:00:00
# 2    2022-01-01 02:00:00
# 3    2022-01-01 03:00:00
# 4    2022-01-01 04:00:00
# ...                  ...
# 8755 2022-12-31 19:00:00
# 8756 2022-12-31 20:00:00
# 8757 2022-12-31 21:00:00
# 8758 2022-12-31 22:00:00
# 8759 2022-12-31 23:00:00
#
# [8760 rows x 1 columns]

# %%
df['random'] = np.random.rand(df.shape[0])
df
# Out:
#                 datetime    random
# 0    2022-01-01 00:00:00  0.885087
# 1    2022-01-01 01:00:00  0.470645
# 2    2022-01-01 02:00:00  0.076300
# 3    2022-01-01 03:00:00  0.933762
# 4    2022-01-01 04:00:00  0.318256
# ...                  ...       ...
# 8755 2022-12-31 19:00:00  0.088631
# 8756 2022-12-31 20:00:00  0.907415
# 8757 2022-12-31 21:00:00  0.144658
# 8758 2022-12-31 22:00:00  0.406346
# 8759 2022-12-31 23:00:00  0.290396
#
# [8760 rows x 2 columns]

# %%
df.iloc[0,:]
# Out:
# datetime    2022-01-01 00:00:00
# random                 0.885087
# Name: 0, dtype: object

# %%
df = df.set_index(df['datetime'])
df
# Out:
#                                datetime    random
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.885087
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.470645
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.076300
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.933762
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.318256
# ...                                 ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.088631
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.907415
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.144658
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.406346
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.290396
#
# [8760 rows x 2 columns]

# %%
df.index.year
df['year'] = df.index.year
df['month'] = df.index.month
df['day'] = df.index.day
df[df['month'] == 1]
# Out:
#                                datetime    random  year  month  day
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.885087  2022      1    1
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.470645  2022      1    1
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.076300  2022      1    1
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.933762  2022      1    1
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.318256  2022      1    1
# ...                                 ...       ...   ...    ...  ...
# 2022-01-31 19:00:00 2022-01-31 19:00:00  0.112600  2022      1   31
# 2022-01-31 20:00:00 2022-01-31 20:00:00  0.496966  2022      1   31
# 2022-01-31 21:00:00 2022-01-31 21:00:00  0.879168  2022      1   31
# 2022-01-31 22:00:00 2022-01-31 22:00:00  0.756436  2022      1   31
# 2022-01-31 23:00:00 2022-01-31 23:00:00  0.431319  2022      1   31
#
# [744 rows x 5 columns]

# %%
#adicionar sazonalidade
tt = np.arange(0,df.shape[0],1)
print(tt.shape)
df['sazonal'] = np.cos(tt/(8760/(2*np.pi)))
df['TimeSeries'] = 10*df['sazonal'] + df['random']
#df['sazonal'].plot()
df['TimeSeries'].plot(color='red')
# Out:
# (8760,)
# <Axes: xlabel='datetime'>

# %%
# salvar meu dataframe
df.to_csv(r'D:\ENS410064\Dados\ExAulas\noise2022.csv')

# %%
# abrindo .csv
path = 'D:/ENS410064/Dados/ExAulas/'
dataSino = pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[153], line 3
#       1 # abrindo .csv
#       2 path = 'D:/ENS410064/Dados/ExAulas/'
# ----> 3 dataSino = pd.read_csv(path)
#
# File D:\ENS410064\pyEnv\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File D:\ENS410064\pyEnv\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File D:\ENS410064\pyEnv\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File D:\ENS410064\pyEnv\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File D:\ENS410064\pyEnv\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'D:/ENS410064/Dados/ExAulas/'

# %%
# criando uma funcao
def criaRuido(path, year):

    """esta funcao cria um ruido aleatorio com sazonalidade"""
    
    #criando um dataframe
    df = pd.DataFrame()

    #criando vetor temporal
    dtime = np.arange(np.datetime64(str(year)+"-01-01"), np.datetime64(str(year)+"-01-01") , np.timedelta64 (1, "h"))
    df['datetime'] = dtime
    
    #montando um df
    df['random'] = np.random.rand(df.shape[0])
    
    #datetime como index do df
    df = df.set_index(df['datetime'])

    df.index.year
    df['year'] = df.index.year
    df['month'] = df.index.month
    df['day'] = df.index.day

    #adicionar sazonalidade
    tt = np.arange(0,df.shape[0],1)
    print(tt.shape)
    df['sazonal'] = np.cos(tt/(8760/(2*np.pi)))
    df['TimeSeries'] = 10*df['sazonal'] + df['random']
    
    #salvar csv
    df.to_csv(path+'/noise_'+str(year)+'.csv')

    return df

# %%
criaRuido('D:/ENS410064/Dados/ExAulas' , 2021 )

# %%
anos = [2001, 2030, 2032, 2053]

for ano in anos:
    print(ano)
    df = criaRuido(path, ano)
# Out:
# 2001
# (0,)
# 2030
# (0,)
# 2032
# (0,)
# 2053
# (0,)

# %%
import os
files = os.listdir(path)
print(files)

allData = []

for file in files:
    if file.endswith('.csv'):
        print(file)
        data = pd.read_csv(path+file)
        allData.append(data)
# Out:
# ['noise2021.csv', 'noise2022.csv', 'noise_2001.csv', 'noise_2021.csv', 'noise_2030.csv', 'noise_2032.csv', 'noise_2053.csv']
# noise2021.csv
# noise2022.csv
# noise_2001.csv
# noise_2021.csv
# noise_2030.csv
# noise_2032.csv
# noise_2053.csv
